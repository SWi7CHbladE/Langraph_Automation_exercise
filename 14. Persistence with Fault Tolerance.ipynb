# %% [markdown]
# # Persistence with fault tolerance
# Here we create a workflow to check out the functionality of fault tolerance using persistence

# %% [markdown]
# ## 1. Import dependencies

# %%
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.sqlite import SqliteSaver                           # This is the tool that we will use to save the state permanently in the sqlite database as checkpoints
from langchain_ollama.chat_models import ChatOllama
from typing import TypedDict
import sqlite3
import time

# %% [markdown]
# This is for graphing purpose

# %%
import nest_asyncio
nest_asyncio.apply()
from langchain_core.runnables.graph import MermaidDrawMethod
from IPython.display import Image

# %% [markdown]
# ## 2. Linking the model

# %%
llm = ChatOllama(model="llama3.1:8b")

# %% [markdown]
# ## 3. Create a state

# %%
class JokeState(TypedDict):                      # The JokeState inherits a TypedDict
    topic: str
    joke: str
    explanation: str

# %% [markdown]
# ## 4. Define the function for the graph node

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def wait(state: JokeState):
    print("Sleeping for 30 seconds, manually crash the application")
    time.sleep(30)
    return state

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %% [markdown]
# ## 5. Create the graph

# %%
# Declare the graph:
graph = StateGraph(JokeState)                    # The StateGraph takes the state as a parameter, signifying that the "state" will be exchanged between the nodes through the edges.

# Add a nodes/states to the graph:
graph.add_node('generate_joke', generate_joke)
graph.add_node('wait', wait)
graph.add_node('generate_explanation', generate_explanation)

# Add the sequential edges:
graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'wait')
graph.add_edge('wait', 'generate_explanation')
graph.add_edge('generate_explanation', END)

# %% [markdown]
# ### Incorporate the checkpointer

# %%
conn = sqlite3.connect(database="persistence_2.db", check_same_thread=False)           # This will create the DB in case it didnot exist earlier.
checkpointer = SqliteSaver(conn)

# %% [markdown]
# ## 6. Compile the graph while incorporating the checkpointer

# %%
workflow = graph.compile(checkpointer=checkpointer)

# %% [markdown]
# ## 7. The Graph

# %%
from IPython.display import Image
Image(workflow.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER))

# %% [markdown]
# # 8. Incorporate the thread in config
# To incorporate persistence, we are required to mention threads for each conversation, so that two different conversations do not pollute each other.

# %%
config1 = {"configurable": {"thread_id": "1"}}

# %% [markdown]
# ## 9. Crash the code

# %%
# First Thread
try:
    final_state = workflow.invoke({'topic':'pizza'}, config=config1)
    print(final_state)
except KeyboardInterrupt:
    print("Interrupted (simulated crash)")
# Out:
# Sleeping for 30 seconds, manually crash the application
# Interrupted (simulated crash)

# %% [markdown]
# ## 10. Rerun the code from the checkpoint

# %%
final_state = workflow.invoke(None, config=config1)
print(final_state)
# Out:
# Sleeping for 30 seconds, manually crash the application
# {'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)", 'explanation': 'Here\'s an explanation of the joke:\n\nThe joke relies on wordplay to create humor. The phrase "feeling crusty" has a double meaning here. In everyday language, someone who is "feeling crusty" might be describing a person who is irritable or in a bad mood. However, the joke takes this expression literally by referencing the fact that a pizza has a crust – a characteristic part of its composition.\n\nThe punchline is funny because it subverts our expectation of what "feeling crusty" typically means. Instead of being a metaphor for a person\'s emotional state, it becomes a clever pun related to the pizza itself. The joke requires a quick mental shift to recognize the wordplay and appreciate the humor in it.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)", 'explanation': 'Here\'s an explanation of the joke:\n\nThe joke relies on wordplay to create humor. The phrase "feeling crusty" has a double meaning here. In everyday language, someone who is "feeling crusty" might be describing a person who is irritable or in a bad mood. However, the joke takes this expression literally by referencing the fact that a pizza has a crust – a characteristic part of its composition.\n\nThe punchline is funny because it subverts our expectation of what "feeling crusty" typically means. Instead of being a metaphor for a person\'s emotional state, it becomes a clever pun related to the pizza itself. The joke requires a quick mental shift to recognize the wordplay and appreciate the humor in it.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2595-369f-67fa-8008-7d24a72abcb3'}}, metadata={'source': 'loop', 'step': 8, 'parents': {}}, created_at='2025-10-26T10:48:36.977242+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2594-4ad2-629f-8007-762a976fcae9'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)", 'explanation': 'Here\'s an explanation of the joke:\n\nThe joke relies on wordplay to create humor. The phrase "feeling crusty" has a double meaning here. In everyday language, someone who is "feeling crusty" might be describing a person who is irritable or in a bad mood. However, the joke takes this expression literally by referencing the fact that a pizza has a crust – a characteristic part of its composition.\n\nThe punchline is funny because it subverts our expectation of what "feeling crusty" typically means. Instead of being a metaphor for a person\'s emotional state, it becomes a clever pun related to the pizza itself. The joke requires a quick mental shift to recognize the wordplay and appreciate the humor in it.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2595-369f-67fa-8008-7d24a72abcb3'}}, metadata={'source': 'loop', 'step': 8, 'parents': {}}, created_at='2025-10-26T10:48:36.977242+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2594-4ad2-629f-8007-762a976fcae9'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)", 'explanation': 'Here\'s an explanation of the joke:\n\nThe joke is a play on words, using a pun to create humor. The word "crusty" has multiple meanings here:\n\n1. A crust is a hard outer layer that covers bread, such as pizza dough.\n2. To be feeling "crusty" can also mean being in a bad mood or irritable.\n\nThe joke sets up the expectation that the answer will be related to the pizza\'s physical properties (e.g., it\'s too thick, it\'s too spicy). But instead, it subverts this expectation by using the secondary meaning of "crusty" to imply that the pizza is feeling upset. The punchline is a clever wordplay on the double meaning of "crusty," creating a humorous connection between the pizza\'s emotional state and its physical characteristics.\n\nThe joke relies on a quick mental shift from one interpretation to the other, which creates a sense of surprise and delight. It\'s a lighthearted and innocuous play on words that uses clever language to create humor!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2594-4ad2-629f-8007-762a976fcae9'}}, metadata={'source': 'loop', 'step': 7, 'parents': {}}, created_at='2025-10-26T10:48:12.251600+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2592-edf8-65c7-8006-27b8e073dd66'}}, tasks=(PregelTask(id='d9401e35-e388-dfbe-8ec3-21b40576d7e6', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'Here\'s an explanation of the joke:\n\nThe joke relies on wordplay to create humor. The phrase "feeling crusty" has a double meaning here. In everyday language, someone who is "feeling crusty" might be describing a person who is irritable or in a bad mood. However, the joke takes this expression literally by referencing the fact that a pizza has a crust – a characteristic part of its composition.\n\nThe punchline is funny because it subverts our expectation of what "feeling crusty" typically means. Instead of being a metaphor for a person\'s emotional state, it becomes a clever pun related to the pizza itself. The joke requires a quick mental shift to recognize the wordplay and appreciate the humor in it.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)", 'explanation': 'Here\'s an explanation of the joke:\n\nThe joke is a play on words, using a pun to create humor. The word "crusty" has multiple meanings here:\n\n1. A crust is a hard outer layer that covers bread, such as pizza dough.\n2. To be feeling "crusty" can also mean being in a bad mood or irritable.\n\nThe joke sets up the expectation that the answer will be related to the pizza\'s physical properties (e.g., it\'s too thick, it\'s too spicy). But instead, it subverts this expectation by using the secondary meaning of "crusty" to imply that the pizza is feeling upset. The punchline is a clever wordplay on the double meaning of "crusty," creating a humorous connection between the pizza\'s emotional state and its physical characteristics.\n\nThe joke relies on a quick mental shift from one interpretation to the other, which creates a sense of surprise and delight. It\'s a lighthearted and innocuous play on words that uses clever language to create humor!'}, next=('wait',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2592-edf8-65c7-8006-27b8e073dd66'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2025-10-26T10:47:35.671945+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2592-c7cb-67be-8005-82affb077e4e'}}, tasks=(PregelTask(id='ce00574c-ec89-3851-5e2c-81eedaff72db', name='wait', path=('__pregel_pull', 'wait'), error=None, interrupts=(), state=None, result={'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)", 'explanation': 'Here\'s an explanation of the joke:\n\nThe joke is a play on words, using a pun to create humor. The word "crusty" has multiple meanings here:\n\n1. A crust is a hard outer layer that covers bread, such as pizza dough.\n2. To be feeling "crusty" can also mean being in a bad mood or irritable.\n\nThe joke sets up the expectation that the answer will be related to the pizza\'s physical properties (e.g., it\'s too thick, it\'s too spicy). But instead, it subverts this expectation by using the secondary meaning of "crusty" to imply that the pizza is feeling upset. The punchline is a clever wordplay on the double meaning of "crusty," creating a humorous connection between the pizza\'s emotional state and its physical characteristics.\n\nThe joke relies on a quick mental shift from one interpretation to the other, which creates a sense of surprise and delight. It\'s a lighthearted and innocuous play on words that uses clever language to create humor!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)", 'explanation': 'Here\'s an explanation of the joke:\n\nThe joke is a play on words, using a pun to create humor. The word "crusty" has multiple meanings here:\n\n1. A crust is a hard outer layer that covers bread, such as pizza dough.\n2. To be feeling "crusty" can also mean being in a bad mood or irritable.\n\nThe joke sets up the expectation that the answer will be related to the pizza\'s physical properties (e.g., it\'s too thick, it\'s too spicy). But instead, it subverts this expectation by using the secondary meaning of "crusty" to imply that the pizza is feeling upset. The punchline is a clever wordplay on the double meaning of "crusty," creating a humorous connection between the pizza\'s emotional state and its physical characteristics.\n\nThe joke relies on a quick mental shift from one interpretation to the other, which creates a sense of surprise and delight. It\'s a lighthearted and innocuous play on words that uses clever language to create humor!'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2592-c7cb-67be-8005-82affb077e4e'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2025-10-26T10:47:31.668972+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2592-c7c9-6414-8004-0da413ff719e'}}, tasks=(PregelTask(id='badeb0e2-4396-807c-1d35-38b892e6d41a', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)"}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)", 'explanation': 'Here\'s an explanation of the joke:\n\nThe joke is a play on words, using a pun to create humor. The word "crusty" has multiple meanings here:\n\n1. A crust is a hard outer layer that covers bread, such as pizza dough.\n2. To be feeling "crusty" can also mean being in a bad mood or irritable.\n\nThe joke sets up the expectation that the answer will be related to the pizza\'s physical properties (e.g., it\'s too thick, it\'s too spicy). But instead, it subverts this expectation by using the secondary meaning of "crusty" to imply that the pizza is feeling upset. The punchline is a clever wordplay on the double meaning of "crusty," creating a humorous connection between the pizza\'s emotional state and its physical characteristics.\n\nThe joke relies on a quick mental shift from one interpretation to the other, which creates a sense of surprise and delight. It\'s a lighthearted and innocuous play on words that uses clever language to create humor!'}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2592-c7c9-6414-8004-0da413ff719e'}}, metadata={'source': 'input', 'step': 4, 'parents': {}}, created_at='2025-10-26T10:47:31.668055+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b258b-e126-673e-8003-10a122142aec'}}, tasks=(PregelTask(id='8d36df6c-5472-a73b-da88-82f7209a65ea', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)", 'explanation': 'Here\'s an explanation of the joke:\n\nThe joke is a play on words, using a pun to create humor. The word "crusty" has multiple meanings here:\n\n1. A crust is a hard outer layer that covers bread, such as pizza dough.\n2. To be feeling "crusty" can also mean being in a bad mood or irritable.\n\nThe joke sets up the expectation that the answer will be related to the pizza\'s physical properties (e.g., it\'s too thick, it\'s too spicy). But instead, it subverts this expectation by using the secondary meaning of "crusty" to imply that the pizza is feeling upset. The punchline is a clever wordplay on the double meaning of "crusty," creating a humorous connection between the pizza\'s emotional state and its physical characteristics.\n\nThe joke relies on a quick mental shift from one interpretation to the other, which creates a sense of surprise and delight. It\'s a lighthearted and innocuous play on words that uses clever language to create humor!'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b258b-e126-673e-8003-10a122142aec'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2025-10-26T10:44:26.422855+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b258a-b1d3-6eb5-8002-9f56b4a4e9ce'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)"}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b258a-b1d3-6eb5-8002-9f56b4a4e9ce'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-10-26T10:43:54.617196+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2586-cd9c-6dbe-8001-b733d43e3bf1'}}, tasks=(PregelTask(id='12395749-bd52-6091-56f6-514005a488ad', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'Here\'s an explanation of the joke:\n\nThe joke is a play on words, using a pun to create humor. The word "crusty" has multiple meanings here:\n\n1. A crust is a hard outer layer that covers bread, such as pizza dough.\n2. To be feeling "crusty" can also mean being in a bad mood or irritable.\n\nThe joke sets up the expectation that the answer will be related to the pizza\'s physical properties (e.g., it\'s too thick, it\'s too spicy). But instead, it subverts this expectation by using the secondary meaning of "crusty" to imply that the pizza is feeling upset. The punchline is a clever wordplay on the double meaning of "crusty," creating a humorous connection between the pizza\'s emotional state and its physical characteristics.\n\nThe joke relies on a quick mental shift from one interpretation to the other, which creates a sense of surprise and delight. It\'s a lighthearted and innocuous play on words that uses clever language to create humor!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)"}, next=('wait',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2586-cd9c-6dbe-8001-b733d43e3bf1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-10-26T10:42:10.156475+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2586-8664-6644-8000-6c111a2a1e5d'}}, tasks=(PregelTask(id='a6b7af04-7091-164c-67c9-595193c45de0', name='wait', path=('__pregel_pull', 'wait'), error=None, interrupts=(), state=None, result={'topic': 'pizza', 'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)"}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2586-8664-6644-8000-6c111a2a1e5d'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-10-26T10:42:02.688453+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2586-8662-65eb-bfff-933e676ff2c0'}}, tasks=(PregelTask(id='97e95d80-422c-5c5f-0140-02875e11831d', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Here's one:\n\nWhy was the pizza in a bad mood?\n\nBecause it was feeling crusty! (get it?)"}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b2586-8662-65eb-bfff-933e676ff2c0'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-10-26T10:42:02.687631+00:00', parent_config=None, tasks=(PregelTask(id='91b1af3c-4be5-b614-16b0-e9406ef55061', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]
